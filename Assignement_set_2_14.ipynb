# %%
Q1. Is an assignment operator like += only for show? Is it possible that it would lead to faster results at the runtime?

Answer:

+= helps in reducing number of lines required to achieve the objective, hence helps in reducing runtime errors

Q2. What is the smallest number of statements you'd have to write in most programming languages to replace the Python expression a, b = a + b, a?

Answer:

a = a+b,
b =a


Q3. In Python, what is the most effective way to set a list of 100 integers to 0?

Answer:

Using for loop

Q4. What is the most effective way to initialise a list of 99 integers that repeats the sequence 1, 2, 3? S If necessary, show step-by-step instructions on how to accomplish this.

Answer:

i =1

n =99

ln= []
while len(ln) < n:
	
	if i <4:
		ln.append(i)
		i += 1
	else:
		i= 1

print(ln)

Q5. If you're using IDLE to run a Python application, explain how to print a multidimensional list as efficiently?

Answer:

Using for loop and print function

Q6. Is it possible to use list comprehension with a string? If so, how can you go about doing it?

Answer:

Using for loop access characters using their index values

Q7. From the command line, how do you get support with a user-written Python programme? Is this possible from inside IDLE?

Answer:

if python 3.7 is added to path variables then support from command line is possible

similarly if Python 3.7 is saved in path of IDLE, the same can be achieved

Q8. Functions are said to be “first-class objects” in Python but not in most other languages, such as C++ or Java.
What can you do in Python with a function (callable object) that you can't do in C or C++?

Answer:

The functions are object type which can be passed to other functions as arguments or take them as values from
other functions

Q9. How do you distinguish between a wrapper, a wrapped feature, and a decorator?

Answer:
    
wrapper is decorator that wraps a feature to the class with the same interface, while a wrapped feature is the 
function that is wrapped 

Q10. If a function is a generator function, what does it return?

Answer:
    
an object

Q11. What is the one improvement that must be made to a function in order for it to become a generator
function in the Python language?

Answer:
    
Using yeild statements whenever a function is called

Q12. Identify at least one benefit of generators.

Answer:
    
    It is iterable and encapsulation is possible
