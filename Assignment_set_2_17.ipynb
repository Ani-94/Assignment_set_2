# %%
Q1. Explain the difference between greedy and non-greedy syntax with visual terms in as few words as possible.
What is the bare minimum effort required to transform a greedy pattern into a non-greedy one? 
What characters or characters can you introduce or change?

Answer:
    
    Greedy syntax takes the available best model to evaluate and does not think whether an overall best result is achieved
    or not
    To convert the greedy to non greedy the '*' should be followed by '?' and '*' to be removed


Q2. When exactly does greedy versus non-greedy make a difference? 
What if you're looking for a non-greedy match but the only one available is greedy?

Answer:
    
    The greedy will wait for initial match and returns but if the rest of the expressions are to be compared then
    we would need non-greedy

Q3. In a simple match of a string, which looks only for one match and does not do any replacement,
is the use of a nontagged group likely to make any practical difference?

Answer:
    No it does not 

Q4. Describe a scenario in which using a nontagged category would have a significant impact on the program's outcomes.

Answer:
    To capture minor groups

Q5. Unlike a normal regex pattern, a look-ahead condition does not consume the characters it examines.
Describe a situation in which this could make a difference in the results of your programme.

Answer:
    It best used when the search string is to find any possible match ahead in the string

Q6. In standard expressions, what is the difference between positive look-ahead and negative look-ahead?

Answer:
    Positive look ahead will look for the presence of the pattern ahead but search for matc, while the negative look ahead
 absence of the string in the search string   

Q7. What is the benefit of referring to groups by name rather than by number in a standard expression?

Answer:
    The partial search for numbers during greedy sntax would result in wrong search

Q8. Can you identify repeated items within a target string using named groups, as in "The cow jumped over the moon"?

Answer:
    Yes

Q9. When parsing a string, what is at least one thing that the Scanner interface does for you that the re.findall 
feature does not?

Answer:
    Scans through a non alphanumerical text also

Q10. Does a scanner object have to be named scanner?

Answer:
    no
